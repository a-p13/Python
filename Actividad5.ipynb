# %% [markdown]
# # **Construcción de programas que toman decisiones - IF**

# %% [markdown]
# Andrea Pintor Valencia
#
# A01067424
#
# 12 enero 2022
#
# https://colab.research.google.com/drive/1_8EaE5Rx5HGdNx4pxbIzwvN1S2tgOvL7?authuser=3#scrollTo=UGIfGPFW7M5e

# %% [markdown]
# ###Problema 1. Escribe un programa que ordene en forma ascendente (menor a mayor) tres números enteros a, b y c (no utilices funciones de ordenamiento).Los tres valores son proporcionados por el usuario; el programa deberá desplegar los tres números de menor a mayor

# %%
a = int(input("Ingresa el número a "))
b = int(input("Ingresa el número b "))
c = int(input("Ingresa el número c "))

if a <= b and a <= c and b <= c:
  print(a)
  print(b)
  print(c)

elif a < b and a < c and c < b:
  print(a)
  print(c)
  print(b)

elif b < a and b < c and a < c:
  print(b)
  print(a)
  print(c)

elif b < a and b < c and c < a:
  print(b)
  print(c)
  print(a)

elif c < a and c < b and a < b:
  print(c)
  print(a)
  print(b)

elif c < a and c < b and b < a:
  print(c)
  print(b)
  print(a)
# Out:
# Ingresa el número a 6
# Ingresa el número b 8
# Ingresa el número c 3
# 3
# 6
# 8

# %% [markdown]
# ### Desarrolla un programa en Python que calcule el índice de masa corporal (IMC).
#
# ### El índice de masa corporal (IMC) se utiliza para determinar si la proporción de peso y altura de una persona es adecuada. El IMC se puede calcular utilizando la siguiente fórmula:
#
#
# ### Donde el peso debe darse en kilogramos y la altura en metros; ambas entradas son datos de punto flotante, que deberás solicitar al usuario.
#
# ### De acuerdo con el resultado del valor del índice de masa corporal, despliega en pantalla la descripción correspondiente con base en la siguiente tabla:

# %%
peso = float(input("Ingresa tu peso en kg "))
altura = float(input("Ingresa tu altura en metros "))

imc = peso / (altura ** 2)

print("Tu Índice de Masa Corporal (IMC) es de, ", round(imc, 2))
print("Tu IMC indica que te encuentras en el siguiente rango: ")

if imc < 20: 
  print("Peso bajo")

elif imc < 25 and imc >= 20: 
  print("Peso normal")

elif imc < 30 and imc >= 25:
  print("Sobrepeso")

elif imc < 40 and imc >= 30:
  print("Obesidad")

else:
  print("Fuera de rango")
# Out:
# Ingresa tu peso en kg 60
# Ingresa tu altura en metros 1.60
# Tu Índice de Masa Corporal (IMC) es de,  23.44
# Tu IMC indica que te encuentras en el siguiente rango:
# Peso normal
