# %% [markdown]
# # **Programas con datos estructurados Strings**

# %% [markdown]
# Andrea Pintor Valencia
#
# A01067424
#
# 27 enero 2022
#
# https://colab.research.google.com/drive/1ZHNi7qACnOwJeQD0vn7-KulgjEKLoxQW?authuser=3#scrollTo=R83TlqOuGAh2

# %% [markdown]
# # Problema 1.
# Escribe una función que reciba como parámetro una cadena de texto y como resultado imprima la cadena en mayúsculas.
#
# cadena = "Armando Escándalos escribe este código, aquel código y el mismo código"

# %%
string = "Armando Escándalos escribe este código, aquel código y el mismo código"

def mayusculas (cadena):

  cadena.upper() #no almacena
  
  print(cadena. upper())

mayusculas(string)
# Out:
# ARMANDO ESCÁNDALOS ESCRIBE ESTE CÓDIGO, AQUEL CÓDIGO Y EL MISMO CÓDIGO

# %% [markdown]
# #Problema 2.
# Escribe una función que reciba dos parámetros: un texto y una letra. La función deberá imprimir la cadena, pero en cada letra diferente de “letra” deberá escribir asteriscos.

# %%
texto = "Esta cadena de texto será modificada"

letra = "a"

def asteriscos(texto, letra):
  string = ""
  
  for _ in texto:
    if _ != letra:
      string = string + "*"
    else:
      string = string + "a"

  print(string)


asteriscos(texto, letra)
# Out:
# ***a**a***a**********************a*a

# %% [markdown]
# # Problema 3.
# Escribe una función que recibe como parámetro un texto. La función deberá eliminar todos los espacios en blanco de la cadena original.
#
# cadena = "Esta cadena de texto no tendrá espacios en blanco"

# %%
texto = "Esta cadena de texto no tendrá espacios en blanco"

def eliminar_espacios(texto):
  
  print(texto.replace(" ", ""))

eliminar_espacios(texto)
# Out:
# Estacadenadetextonotendráespaciosenblanco

# %% [markdown]
# # Problema 4.
# Escribe una función que recibe como parámetro una cadena de texto y una subcadena. La función deberá contar cuántas veces se repite la subcadena en la cadena original y devolver dicho número

# %%
cadena = "Armando Escándalos escribe este código, aquel código y el mismo código"

subcadena = "código"

def contar_subcadena (cadena, subcadena):
  
  contador = cadena.count(subcadena)

  print(f"La subcadena \"{subcadena}\" se repite {contador} veces.")

contar_subcadena(cadena, subcadena)
# Out:
# La subcadena "código" se repite 3 veces.
