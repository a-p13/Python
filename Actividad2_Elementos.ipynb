# %% [markdown]
# Actividad 2 - Elementos básicos de Python

# %% [markdown]
# Andrea Pintor Valencia
#
# A01067424
#
# 6 enero 2022
#
# https://colab.research.google.com/drive/18x7Q2QUSH-dpW5-93bYmM4kQ0rb8okdW?authuser=3#scrollTo=8sQS8vQvThO0

# %% [markdown]
# ## Operaciones

# %%
2+2
# Out:
# 4

# %%
2*6
# Out:
# 12

# %%
"Ja"*5
# Out:
# 'JaJaJaJaJa'

# %% [markdown]
# ## Tipos de datos

# %%
edad =18

# %%
type(edad) #tipo de dato entero (int)
# Out:
# int

# %%
dolar = 20.45

# %%
type (dolar) #tipo de dato flotante (decimal)
# Out:
# float

# %%
sensei = "German"

# %%
type (sensei) #tipo de dato texto (str)
# Out:
# str

# %%
vacuna_covid = True

# %%
type (vacuna_covid)  #tipo de dato booleano (solo puede ser V o F)
# Out:
# bool

# %%
covid = False

# %% [markdown]
# ## Mostrar un dato en pantalla

# %%
print(sensei)
# Out:
# German

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %%
print(4+5)
# Out:
# 9

# %% [markdown]
# ## Leer un dato

# %%
edad=input()
# Out:
# 28

# %%
print("Ingresa tu edad: ")
edad =input()
print ("Tu edad es ",edad)
# Out:
# Ingresa tu edad:
# 65
# Tu edad es  65

# %%
print("Ingresa tu nombre: ")
nombre =input()
print ("Tu nombre es ",nombre)
# Out:
# Ingresa tu nombre:
# Andrea
# Tu nombre es  Andrea

# %% [markdown]
# ## Convertir un tipo de dato

# %%
dolar=float(input())
# Out:
# 23

# %%
precio = dolar * 1.16

# %%
print(precio)
# Out:
# 23.721999999999998
