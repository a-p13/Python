# %%
#pandas
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dt = pd.read_csv("DA_Hospitalizados.csv")

# %%
#Mostrar numero de columnas y numero de filas
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9243 entries, 0 to 9242
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Fecha        9243 non-null   object
#  1   Institución  9243 non-null   object
#  2   Pacientes    9180 non-null   float64
#  3   Positivos    9180 non-null   float64
#  4   En_estudio   9180 non-null   float64
# dtypes: float64(3), object(2)
# memory usage: 361.2+ KB

# %%
#estadisticas
media = dt.mean()
print(media)
# Out:
# Pacientes     49.953813
# Positivos     30.850109
# En_estudio    19.085512
# dtype: float64
# <ipython-input-5-2b481d23818f>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   media = dt.mean()

# %%
mediana = dt.median()
print(mediana)
# Out:
# Pacientes     3.0
# Positivos     2.0
# En_estudio    0.0
# dtype: float64
# <ipython-input-6-58855bfd55dd>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mediana = dt.median()

# %%
desviacion = dt.std()
print(desviacion)
# Out:
# Pacientes     125.070461
# Positivos      73.057873
# En_estudio     54.949644
# dtype: float64
# <ipython-input-7-9d875b4d858a>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   desviacion = dt.std()
