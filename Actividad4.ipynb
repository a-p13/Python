# %% [markdown]
# # Actividad 4. Construcción de programas que utilizan funciones

# %% [markdown]
# Andrea Pintor
#
# A01067424
#
# 11 enero de 2022
#
# https://colab.research.google.com/drive/1Bcm-2ydf_V_DghUB4F8u-LiekaMqk0y1?authuser=3#scrollTo=m_05Q2pb2usI

# %% [markdown]
# ### Problema 1
#
# ¿Qué aparece en la pantalla si se ejecuta el siguiente código de Python?:
#
# def uno (a, b) :
#
#      a = a + 5
#      b += 10
#      print(a, b)
#      return b
#
# def main() :
#
#      x = 5
#      y = 8
#      z = uno(x, y)
#      print(x, y, z)
#
# main()
#
# **Se imprimen las coordenadas (10, 18) de la función uno y las coordenadas (5, 8, 18) de la función main**

# %% [markdown]
# ### Problema 2. Escribe una función llamada equivalente que reciba como parámetro una cantidad de horas, minutos y segundos, y regrese como valor de retorno el tiempo equivalente en segundos.Por ejemplo:
#
# ### Si la función recibe los valores horas = 2, minutos = 20 y segundos = 8, regresará el valor 8408.
#
# ### Nota que la función no mostrará nada, solo regresa como valor de retorno la cantidad de segundos equivalente.
#
# ### Ahora, escribe una función main en la que pidas al usuario teclear cuánto tiempo en horas, minutos y segundos han tardado 2 procesos. Después de pedir el tiempo que dura cada proceso, muestra el tiempo equivalente en segundos de dicho proceso.

# %%
def equivalente (horas,minutos, segundos): #funcion que te da el tiempo total en segundos 
  tiempo_en_segundos = (horas * 3600) + (minutos * 60) + (segundos)
  return tiempo_en_segundos

def main():
  horas = int(input("Escribe las horas que tardó el proceso 1 "))
  minutos = int(input("Escribe los minutos que tardó el proceso 1 "))
  segundos = int(input("Escribe los segundos que tardó el proceso 1 "))
  segundos_calculados = equivalente (horas, minutos, segundos)
  print("El tiempo en segundos del proceso 1 es de ", segundos_calculados)

  horas = int(input("Escribe las horas que tardó el proceso 2 "))
  minutos = int(input("Escribe los minutos que tardó el proceso 2 "))
  segundos = int(input("Escribe los segundos que tardó el proceso 2 "))
  segundos_calculados = equivalente (horas, minutos, segundos)
  print("El tiempo en segundos del proceso 2 es de ", segundos_calculados)

main()
# Out:
# Escribe las horas que tardó el proceso 1 2
# Escribe los minutos que tardó el proceso 1 4
# Escribe los segundos que tardó el proceso 1 2
# El tiempo en segundos del proceso 1 es de  7442
# Escribe las horas que tardó el proceso 2 1
# Escribe los minutos que tardó el proceso 2 4
# Escribe los segundos que tardó el proceso 2 6
# El tiempo en segundos del proceso 2 es de  3846

# %% [markdown]
# ### Escribe una función llamada area_rectangulo que reciba como parámetro el largo y ancho de un rectángulo y que regresa como valor de retorno el área del rectángulo.
#
# ### Escribe una función llamada perimetro_rectangulo que reciba como parámetro el largo y ancho de un rectángulo y que regresa como valor de retorno el perímetro del rectángulo.
#
# ###Observa que dentro de las funciones no mostrarás nada, solo regresarás el valor calculado usando return.
#
# ###Escribe ahora una función main que pregunte al usuario el largo y ancho del rectángulo (puedes pedir una clave a para área y p para perímetro) y después muestre el valor correspondiente al cálculo.

# %%
def area_rectangulo (largo, ancho):
  area = largo * ancho

  return area

def perimetro_rectangulo (largo, ancho):
  perimetro = (2 * largo) + (2 * ancho)

  return perimetro

def main():
  valor_largo = int(input("Escribe el valor de largo del rectángulo "))
  valor_ancho = int(input("Escribe el valor de ancho del rectángulo "))

  print("El área del rectángulo es de ", area_rectangulo (valor_largo, valor_ancho))
  print("El perímetro del rectángulo es de ",perimetro_rectangulo (valor_largo, valor_ancho))

main()
# Out:
# Escribe el valor de largo del rectángulo 8
# Escribe el valor de ancho del rectángulo 2
# El área del rectángulo es de  16
# El perímetro del rectángulo es de  20
