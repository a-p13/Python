# %% [markdown]
# # **Examen Final**

# %% [markdown]
# Andrea Pintor Valencia
#
# A01067424
#
# 03 febrero 2022
#
# https://colab.research.google.com/drive/1IrY-uoXeWtMe1lYZTS48Uj7Wv-YTDMfo?authuser=3#scrollTo=dc4fVbL2Fcmw

# %%
lista_alimentos = []

def registrar_alimentos():
  
  sublista_alimentos = []
  
  for elemento in range(5):
    sublista_alimentos = []
    id = input("Ingresa el ID del alimento: ")
    nombre = input("Ingresa el nombre del alimento: ")
    precio = float(input("Ingresa el precio del alimento: "))
    
    sublista_alimentos.append(id)
    sublista_alimentos.append(nombre)
    sublista_alimentos.append(precio)
  
    lista_alimentos.append(sublista_alimentos)

  print("Tu registro fue exitoso.")
  return lista_alimentos

registrar_alimentos()
# Out:
# Ingresa el ID del alimento: 1
# Ingresa el nombre del alimento: Tacos
# Ingresa el precio del alimento: 90
# Ingresa el ID del alimento: 2
# Ingresa el nombre del alimento: Enchiladas
# Ingresa el precio del alimento: 100
# Ingresa el ID del alimento: 3
# Ingresa el nombre del alimento: Gorditas
# Ingresa el precio del alimento: 80
# Ingresa el ID del alimento: 4
# Ingresa el nombre del alimento: Flautas
# Ingresa el precio del alimento: 110
# Ingresa el ID del alimento: 5
# Ingresa el nombre del alimento: Refresco
# Ingresa el precio del alimento: 30
# Tu registro fue exitoso.
# [['1', 'Tacos', 90.0],
#  ['2', 'Enchiladas', 100.0],
#  ['3', 'Gorditas', 80.0],
#  ['4', 'Flautas', 110.0],
#  ['5', 'Refresco', 30.0]]

# %%
def menu():
  print("""
Menú de la fonda
ID \t Alimento \t Precio""")
 
  for _ in range(len(lista_alimentos)):
    print(lista_alimentos[_][0], "\t", lista_alimentos[_][1], "\t", "$", lista_alimentos[_][2], "\t")

menu()
# Out:
# Menú de la fonda
# ID 	 Alimento 	 Precio
# 1 	 Tacos 	 $ 90.0
# 2 	 Enchiladas 	 $ 100.0
# 3 	 Gorditas 	 $ 80.0
# 4 	 Flautas 	 $ 110.0
# 5 	 Refresco 	 $ 30.0

# %%
def comprar():
  menu()
  suma = 0
  id = ""
  total = 0
  lista = []

  while id != "pagar":

    id = input("Ingresa el ID del alimento que deseas comprar o \"pagar\" si deseas salir: ")
    
    if id > str(len(lista_alimentos)):
      print("Error. Intenta de nuevo.")
      continue
    elif id == "pagar":
      break

    for _ in range(len(lista_alimentos)):
      subsublista = []
      if id == lista_alimentos[_][0]:
        print(lista_alimentos[_][1],  lista_alimentos[_][2])
        suma = suma + lista_alimentos[_][2]
        lista.append(lista_alimentos[_][1])
        lista.append(lista_alimentos[_][2])
      subsublista.append(lista)

  print("""
    Ticket de compra
Alimento \t Precio""")
  
  iva = suma * .16

  for _ in subsublista:
    print(_)
   

  print("IVA \t $", int(iva))
  total = suma + iva
  print("El total a pagar es $", total)
  print("Buen provecho.")
3
comprar()
# Out:
# Menú de la fonda
# ID 	 Alimento 	 Precio
# 1 	 Tacos 	 $ 90.0
# 2 	 Enchiladas 	 $ 100.0
# 3 	 Gorditas 	 $ 80.0
# 4 	 Flautas 	 $ 110.0
# 5 	 Refresco 	 $ 30.0
# Ingresa el ID del alimento que deseas comprar o "pagar" si deseas salir: 1
# Tacos 90.0
# Ingresa el ID del alimento que deseas comprar o "pagar" si deseas salir: 3
# Gorditas 80.0
# Ingresa el ID del alimento que deseas comprar o "pagar" si deseas salir: 8
# Error. Intenta de nuevo.
# Ingresa el ID del alimento que deseas comprar o "pagar" si deseas salir: 5
# Refresco 30.0
# Ingresa el ID del alimento que deseas comprar o "pagar" si deseas salir: pagar
# Error. Intenta de nuevo.
#
#     Ticket de compra
# Alimento 	 Precio
# ['Tacos', 90.0, 'Gorditas', 80.0, 'Refresco', 30.0]
# IVA 	 $ 32
# El total a pagar es $ 232.0
# Buen provecho.
