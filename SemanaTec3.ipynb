# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("peso_estatura_genero.csv")

# %%
num_Estatura = df["Estatura"].count()
x = df["Peso"]  #np.linspace(1,num_Estatura, num_Estatura)
y = df["Estatura"]

#plt.bar(x,y)
#plt.plot(x,y)
plt.scatter(x,y)
#plt.stackplot(x,y)

plt.show()

# %% [markdown]
# ---

# %%
x = np.linspace(0, 9, num = 1000)
y = np.sin(x)
y2 = np.sin(x**2)/30

plt.figure(figsize=(10,7))

#Subplot 1 (Cols = 2, Rows = 1)
plt.subplot(211)
plt.plot(x,y, "r--*")
plt.title("Funcion Seno")
#plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
#plt.show()

#Subplot 2
plt.subplot(212)
plt.plot(x,y2, "c*")
#plt.ylim(-2, 2)
#plt.xlim(0, 15)
plt.title("Funcion Cuadratica")
plt.xlabel("X")
plt.ylabel("Y2")
plt.legend("y = sin(x)", loc = "best")
plt.grid(True)
plt.show()
