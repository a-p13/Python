# %% [markdown]
# # **Construcción de programas que utilizan listas**

# %% [markdown]
# Andrea Pintor Valencia
#
# A01067424
#
# 24 enero 2022
#
# https://colab.research.google.com/drive/1OQPQ2vIUtvQWwi9y9_Pb49b5JDCzFeZK?authuser=3#scrollTo=U-xL3asMvdZS

# %% [markdown]
# # Problema 1.
# Crea una lista que almancene tu matrícula, nombre y apellido y carrera. Imprime cada uno de los datos en una línea diferente.

# %%
alumno = ["A01067424", "Andrea", "Pintor", "IRS" ]

#forma 1
print(alumno[0])
print(alumno[1])
print(alumno[2])
print(alumno[3])

#forma 2
for num in alumno:
  print(num)
# Out:
# A01067424
# Andrea
# Pintor
# IRS
# A01067424
# Andrea
# Pintor
# IRS

# %% [markdown]
# # Problema 2.
# Crea una lista con el nombre de 3 personas. Imprime cada elemento de la lista mediante un ciclo for.

# %%
personas = ["Andrea", "Jorge", "Alejandra"]

for nombre in personas:
  print(nombre)
# Out:
# Andrea
# Jorge
# Alejandra

# %% [markdown]
# # Problema 3.
# Crea un programa donde el usuario pueda introducir mediante el teclado nombres 3 libros, los cuales deberás ir guardando en una lista. Al final, imprime la lista de libros.

# %%
nombres_libros = []

for num in range(1, 4):
  nombres_libros.append(input("Ingresa el nombre del libro " + str(num) + ": "))

print(nombres_libros)
# Out:
# Ingresa el nombre del libro 1 Mate
# Ingresa el nombre del libro 2 Progra
# Ingresa el nombre del libro 3 Español
# ['Mate', 'Progra', 'Español']
# Mate
# Progra
# Español

# %% [markdown]
# # Problema 4.
# Crea una lista que simule las calificaciones de 10 actividades de un alumno. Supón que debido al excepcional desempeño del alumno, el profesor ha decidido aumentar 5 puntos. Tu programa deberá aumentar a cada calificación los 5 puntos (recordando que la calificación máxima es de 100 y no puede pasarse).

# %%
lista_calificaciones = [100, 95, 98, 97, 60, 80, 100, 80, 80, 96]
  
for nota in range(len(lista_calificaciones)):
  
  if lista_calificaciones[nota] >= 95:
    lista_calificaciones[nota] = 100
    
  else:
    lista_calificaciones[nota] = lista_calificaciones[nota] + 5

print(lista_calificaciones)
# Out:
# [100, 100, 100, 100, 65, 85, 100, 85, 85, 100]

# %% [markdown]
# # Problema 5.
# Escribe una función que convierta un número entero en lista, la función deberá recibir un número entero y regresar una lista con todos los dígitos del numero.
#
# Si el número estero es 575, la lista resultante sería [5,7,5]

# %%
numero = input("Ingresa un número entero: ")
  
def entero(numero):

  lista = list(numero)

  for num in range(len(lista)):
    lista[num] = int(lista[num])

  return lista

entero(numero)
# Out:
# Ingresa un número entero: 958
# [9, 5, 8]
